# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
test = pd.read_csv(r"DataTest.csv")
test
# Out:
#     case                         event                   ts
# 0      2                Order imported  2018-09-02 00:02:33
# 1      2            Suspicious (Fraud)  2018-09-02 00:02:46
# 2      2                 Order checked  2018-09-03 14:26:03
# 3      2               Device hand-out  2018-09-03 14:27:56
# 4      2  Ready for payment processing  2018-09-03 14:27:56
# 5      2      Documents complete (ERP)  2018-09-03 15:50:48
# 6      2              Ready to deliver  2018-09-03 16:31:24
# 7      2                     Delivered  2018-09-04 15:01:13
# 8      2                     Activated  2018-09-04 15:15:37
# 9      2                 Printed (ERP)  2018-09-04 15:15:37
# 10     2       Customer ID transmitted  2018-09-04 17:16:11
# 11     2                      Invoiced  2018-09-04 22:16:06
# 12     2     Return delivery initiated  2018-09-25 08:46:33
# 13     2    Processing return delivery  2018-09-25 09:01:13
# 14     7                Order imported  2018-09-02 00:07:29
# ...

# %%
plt.plot (test.ts, test.case, 'o')
plt.title("Dataset")
plt.xlabel("ts")
plt.ylabel("case")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
brands = pd.read_csv(r"brands.csv")
brands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263253 entries, 0 to 263252
# Data columns (total 2 columns):
# pid      263253 non-null int64
# BRAND    263253 non-null object
# dtypes: int64(1), object(1)
# memory usage: 4.0+ MB

# %%
brandsTop10 = brands.BRAND.value_counts().head(10)
brandsTop10
# Out:
# BRAND_1    205293
# BRAND_6     26359
# BRAND_7     14037
# BRAND_2     10544
# BRAND_0      4715
# BRAND_4      1657
# BRAND_9       384
# BRAND_3       193
# BRAND_8        62
# BRAND_5         9
# Name: BRAND, dtype: int64

# %%
sim = pd.read_csv(r"sim.csv")
sim.info()
simTop10 = sim.SIM.value_counts().head(10)
simTop10
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102822 entries, 0 to 102821
# Data columns (total 2 columns):
# pid    102822 non-null int64
# SIM    102822 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1.6+ MB
# SIM_14    50604
# SIM_34    14275
# SIM_42     9442
# SIM_27     6441
# SIM_44     5896
# SIM_36     5090
# SIM_43     2660
# SIM_16     2326
# SIM_0      1900
# SIM_31      963
# Name: SIM, dtype: int64

# %%
tariff = pd.read_csv(r"tariffs.csv")
tariff.info()
tariffTop10 = tariff.TARIFF.value_counts().head(10)
tariffTop10
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136947 entries, 0 to 136946
# Data columns (total 2 columns):
# pid       136947 non-null int64
# TARIFF    136947 non-null object
# dtypes: int64(1), object(1)
# memory usage: 2.1+ MB
# TARIFF_OPTION_87     79554
# TARIFF_OPTION_97     10541
# TARIFF_OPTION_95      6463
# TARIFF_OPTION_88      5554
# TARIFF_OPTION_137     4297
# TARIFF_OPTION_105     3221
# TARIFF_OPTION_111     3191
# TARIFF_OPTION_110     3191
# TARIFF_OPTION_115     2700
# TARIFF_OPTION_118     1815
# Name: TARIFF, dtype: int64

# %%
# %matplotlib inline
brandsTop10.plot()
